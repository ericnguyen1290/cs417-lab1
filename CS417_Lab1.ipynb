# %% [markdown]
# <a href="https://colab.research.google.com/github/ericnguyen1290/cs417-lab1/blob/main/CS417_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 417 - Lab 1: Google Colab Introduction
# **Date: 1/20/2026**
# This notebook demonstrates basic Python concepts including:
# - Print statements
# - Variables
# - Basic arithmetic operations
# - String formatting

# %%
print("Welcome to Google Colab!")
print("Python makes programming fun!")
# Out:
# Welcome to Google Colab!
# Python makes programming fun!

# %%
favorite_food = "pizza"
favorite_number = 7
favorite_color = "blue"
print("My favorite food is:", favorite_food)
print("My favorite number is:", favorite_number)
print("My favorite color is:", favorite_color)
# Out:
# My favorite food is: pizza
# My favorite number is: 7
# My favorite color is: blue

# %%
player_score = 150
bonus_score = 50

total_score = player_score + bonus_score

print("Total game score is:", total_score)
# Out:
# Total game score is: 200
